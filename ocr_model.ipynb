# %% [markdown]
# <a href="https://www.kaggle.com/code/orestasdulinskas/ocr-model?scriptVersionId=242848697" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # OCR Model Training
# ---
# ## Data preprocessing

# %%
import pandas as pd

# load the annotations
df = pd.read_csv('/kaggle/input/full-annotation-data/via_project_6Sep2024_20h21m_csv (1).csv')

# path to images
image_path = '/kaggle/input/complete-resized-journal-scans/resized_journal_scans/'

# %%
# lists to store the images and labels
images = []
labels = []

# define fixed height 
FIXED_HEIGHT = 45

# add annotations to dataframe
df = df[df['region_attributes'].str.contains('text')]

# %%
import cv2
import albumentations as A

# define image augmentations
aug_pipeline = A.Compose([
    # Rotation and perspective changes
    A.ShiftScaleRotate(shift_limit=0, scale_limit=(-0.4,0), rotate_limit=1, p=0.6, border_mode=cv2.BORDER_CONSTANT, value=(255, 255, 255)),
    A.Perspective(scale=(0, 0.045), fit_output=True, pad_mode=cv2.BORDER_CONSTANT, pad_val=(255, 255, 255), p=0.4),

    # Realistic handwriting variations
    A.ElasticTransform(alpha=1, sigma=0, alpha_affine=0, p=0.4),
    
    # Lighting and contrast variations
    A.GaussianBlur(blur_limit=(1, 3), p=0.4),
    A.RandomBrightnessContrast(brightness_limit=(-0.4,0.3), contrast_limit=(-0.2,0.2), p=0.6),
    A.RandomGamma(gamma_limit=(5, 80), p=0.4),

    # Typical scanning/photo artifacts
    A.GaussNoise(var_limit=(0, 500.0), p=0.4),
    A.ImageCompression(quality_lower=30, quality_upper=100, p=0.4)
])

# %%
import numpy as np

# iterate through the annotations
for index, row in df.iterrows():
    filename = row['filename']
    region_shape = eval(row['region_shape_attributes'])
    region_attr = eval(row['region_attributes'])
    
    # extract bounding box coordinates
    x = region_shape['x']
    y = region_shape['y']
    width = region_shape['width']
    height = region_shape['height']
    
    # extract the text label
    text = region_attr['text']
    
    # load and crop the image
    image = cv2.imread(image_path+filename)
    cropped = image[y:y+height, x:x+width]
    
    # Resize the image to have a fixed height while maintaining aspect ratio
    aspect_ratio = width / height
    new_width = int(FIXED_HEIGHT * aspect_ratio)
    resized_image = cv2.resize(cropped, (new_width, FIXED_HEIGHT))
    
    # convert to grayscale
    resized_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

    # apply augmentation 5 times
    for _ in range(5):
        augmented = aug_pipeline(image=resized_image)
        augmented_image = augmented['image']
    
        # normalize and add channel dimension
        augmented_image = augmented_image.astype(np.float32) / 255.0
        augmented_image = np.expand_dims(augmented_image, axis=-1)

        # add to the lists
        images.append(augmented_image)
        labels.append(text)
    
    # add the original images and labels as well
    original_image = resized_image.astype(np.float32) / 255.0
    original_image = np.expand_dims(original_image, axis=-1)
    images.append(original_image)
    labels.append(text)

# convert label list to array
labels = np.array(labels)

# %%
# size of processed data
len(images)
# Out:
# 13056

# %%
import matplotlib.pyplot as plt
import random

# plot 10 random images to see the effects of augmentation
for i in [random.randint(0, len(images)) for _ in range(10)]:
    print(labels[i])
    plt.figure(figsize=(10, 10))
    plt.imshow(np.squeeze(images[i]), cmap='gray')
    plt.axis('off')
    plt.show()
# Out:
# limbs and body
# to his team and also work on a project
# a lot more in common than ever
# the prompter ends up
# having this massive
# sits on the bottom of the ocean.
# poor get poorer. Also, on a
# tackle any of the
# On top of this,
# hole, yet still, I feel trapped in it.

# %%
import torch
from torch.nn.utils.rnn import pad_sequence

# define the maximum label length
max_label_len = max(len(label) for label in labels)

# character mapping
characters = set("".join(labels)) # get all characters, numbers and symbols in label dataset
char_to_num = {char: i+1 for i, char in enumerate(sorted(characters))} # enumerate characters
char_to_num['<PAD>'] = 0  # add padding token
num_to_char = {i: char for char, i in char_to_num.items()} # create dictionary {number: 'character'}

# encode labels
encoded_labels = []
for label in labels:
    encoded = torch.tensor([char_to_num[char] for char in label], dtype=torch.long)
    encoded_labels.append(encoded)

# pad sequences
padded_labels = pad_sequence(encoded_labels, batch_first=True, padding_value=0)

# make all sequences max length
if padded_labels.shape[1] < max_label_len:
    padding = torch.zeros(padded_labels.shape[0], max_label_len - padded_labels.shape[1], dtype=torch.long)
    padded_labels = torch.cat([padded_labels, padding], dim=1)
else:
    padded_labels = padded_labels[:, :max_label_len]

# %%
import pickle

# save character mapping
with open('num_to_char.pkl', 'wb') as f:
    pickle.dump(num_to_char, f)

# %%
from sklearn.model_selection import train_test_split

# split data for training and validation
train_images, val_images, train_labels, val_labels = train_test_split(images, padded_labels, test_size=0.3, random_state=42)

# %%
from torch.utils.data import Dataset, DataLoader

# define dataset class
class HandwritingDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = torch.tensor(self.images[idx], dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return image, label

def collate_fn(batch):
    images, labels = zip(*batch)
    
    # find max width
    max_width = max(img.shape[1] for img in images)
    
    # pad images to the max dimensions
    padded_images = [torch.nn.functional.pad(img, (0, 0, max_width - img.shape[1], 0)) for img in images]
    
    # stack images
    images = torch.stack(padded_images)
    
    # pad labels
    labels = pad_sequence(labels, batch_first=True, padding_value=0)
    
    return images, labels

def create_dataloader(images, labels, batch_size):
    dataset = HandwritingDataset(images, labels)
    return DataLoader(dataset, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# %%
batch_size=32

train_loader = create_dataloader(train_images, train_labels, batch_size)
val_loader = create_dataloader(val_images, val_labels, batch_size)

# %% [markdown]
# ## Model Architecture

# %%
import torch.nn as nn

class HandwritingRecognitionModel(nn.Module):
    def __init__(self, num_characters):
        super(HandwritingRecognitionModel, self).__init__()
        
        self.cnn = nn.Sequential(
            # first CNN layer
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d(2,2),
            nn.Dropout2d(0.5),
            
            # second CNN layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AvgPool2d(2,2),
            nn.Dropout2d(0.5),
            
            # third CNN layer
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout2d(0.5),
            
            # fourth CNN layer
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout2d(0.5),

            # fifth CNN layer
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU()
        )
        
        self.lstm_input_size = 512 * 12

        # bi-LSTM network
        self.lstm = nn.LSTM(
            input_size=self.lstm_input_size,
            hidden_size=256,
            dropout=0.7,
            num_layers=2,
            bidirectional=True,
            batch_first=True
        )
        
        self.output = nn.Linear(512, num_characters)
    
    def forward(self, x):
        batch_size = x.size(0)
        
        x = x.permute(0, 3, 1, 2)
        x = self.cnn(x)
        x = x.permute(0, 3, 1, 2)
        x = x.reshape(batch_size, x.size(1), -1)
        x, _ = self.lstm(x)
        x = self.output(x)
        
        return nn.functional.log_softmax(x, dim=2)

def build_model(num_characters):
    return HandwritingRecognitionModel(num_characters)

# %%
# define custom loss function
class FocalCTCLoss(nn.Module):
    def __init__(self, blank=0, zero_infinity=False, gamma=2.0):
        super(FocalCTCLoss, self).__init__()
        self.ctc_loss = nn.CTCLoss(blank=blank, zero_infinity=zero_infinity, reduction='none')
        self.gamma = gamma
        
    def forward(self, log_probs, targets, input_lengths, target_lengths):
        
        # calculate CTC loss per example
        individual_losses = self.ctc_loss(log_probs, targets, input_lengths, target_lengths)
        
        # apply focal loss weighting
        pt = torch.exp(-individual_losses)
        focal_weight = (1 - pt) ** self.gamma
        focal_loss = focal_weight * individual_losses
        
        # return mean loss
        return torch.mean(focal_loss)

# %%
# !pip install --quiet editdistance

# %%
import editdistance

# calculate Character Error Rate (CER) for a batch
def calculate_batch_cer(outputs, targets):
    # get predictions
    pred_indices = torch.argmax(outputs, dim=2).cpu().numpy()
    target_indices = targets.cpu().numpy()
    
    batch_size = len(pred_indices)
    total_cer = 0.0
    
    for i in range(batch_size):
        # convert prediction indices to characters and remove duplicates and blanks
        pred_chars = []
        prev_char = None
        for idx in pred_indices[i]:
            if idx != 0 and idx != prev_char:
                pred_chars.append(idx)
            prev_char = idx
        
        # convert target indices to characters (remove padding)
        target_chars = [idx for idx in target_indices[i] if idx != 0]
        
        # calculate edit distance
        edit_dist = editdistance.eval(pred_chars, target_chars)
        
        # calculate CER
        if len(target_chars) > 0:
            cer = edit_dist / len(target_chars)
            total_cer += cer
    
    # return average CER
    return total_cer / batch_size if batch_size > 0 else 0.0

# %% [markdown]
# ## Training function

# %%
import torch.optim as optim
from tqdm import tqdm

def train_model(model, train_loader, val_loader, num_epochs=200, patience=4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.01)
    
    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, 
        max_lr=0.001,
        total_steps=num_epochs * len(train_loader),
        pct_start=0.1,
        anneal_strategy='cos',
        div_factor=25.0,
        final_div_factor=10000.0
    )
    
    criterion = FocalCTCLoss(gamma=2.0)
    
    # early stopping setup
    best_loss = float('inf')
    early_stop_counter = 0
    best_model_state = None
    
    # loss history
    train_losses = []
    val_losses = []
    
    # character error rates
    train_cers = []
    val_cers = []
    
    # learning rates
    lrs = []
    
    # mixed precision setup
    scaler = torch.cuda.amp.GradScaler() if torch.cuda.is_available() else None
    
    for epoch in range(num_epochs):
        # training phase
        model.train()
        train_loss = 0.0
        train_cer = 0.0
        batch_count = 0
        
        # progress bar for training
        progress_bar = tqdm(train_loader, desc=f"Epoch {epoch + 1}/{num_epochs} [Train]")
        
        for batch in progress_bar:
            inputs, targets = batch
            batch_size = inputs.size(0)
            inputs = inputs.to(device)
            targets = targets.to(device)
            
            # calculate sequence lengths
            input_lengths = torch.full(
                size=(batch_size,),
                fill_value=inputs.size(2) // 4,  # adjusted for CNN downsampling
                dtype=torch.long
            ).to(device)
            
            target_lengths = torch.sum(targets != 0, dim=1).to(device)
            
            # mixed precision training
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
                outputs_for_loss = outputs.transpose(0, 1)  # (T, N, C)
                loss = criterion(outputs_for_loss, targets, input_lengths, target_lengths)
            
            # skip batch if loss is infinite or NaN
            if torch.isinf(loss) or torch.isnan(loss):
                continue
            
            optimizer.zero_grad()
            scaler.scale(loss).backward()
            
            # gradient clipping
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            scaler.step(optimizer)
            scaler.update()

            # update learning rate
            scheduler.step()
            lrs.append(scheduler.get_last_lr()[0])
            
            # calculate CER
            batch_cer = calculate_batch_cer(outputs, targets)
            
            # update metrics
            train_loss += loss.item()
            train_cer += batch_cer
            batch_count += 1
            
            # update progress bar
            progress_bar.set_postfix({
                'loss': f"{loss.item():.4f}", 
                'cer': f"{batch_cer:.4f}", 
                'lr': f"{scheduler.get_last_lr()[0]:.6f}"
            })
        
        # calculate average metrics
        avg_train_loss = train_loss / batch_count
        avg_train_cer = train_cer / batch_count
        train_losses.append(avg_train_loss)
        train_cers.append(avg_train_cer)
        
        # validation phase
        model.eval()
        val_loss = 0.0
        val_cer = 0.0
        val_batch_count = 0
        
        # progress bar for validation
        val_progress = tqdm(val_loader, desc=f"Epoch {epoch + 1}/{num_epochs} [Valid]")
        
        with torch.no_grad():
            for batch in val_progress:
                inputs, targets = batch
                batch_size = inputs.size(0)
                inputs = inputs.to(device)
                targets = targets.to(device)
                
                # calculate sequence lengths
                input_lengths = torch.full(
                    size=(batch_size,),
                    fill_value=inputs.size(2) // 4,
                    dtype=torch.long
                ).to(device)
                
                target_lengths = torch.sum(targets != 0, dim=1).to(device)
                
                # forward pass
                outputs = model(inputs)
                outputs_for_loss = outputs.transpose(0, 1)  # (T, N, C)
                
                # skip NaN/Inf losses
                loss = criterion(outputs_for_loss, targets, input_lengths, target_lengths)
                if torch.isinf(loss) or torch.isnan(loss):
                    continue
                
                # calculate CER
                batch_cer = calculate_batch_cer(outputs, targets)
                
                # update metrics
                val_loss += loss.item()
                val_cer += batch_cer
                val_batch_count += 1
                
                # update progress bar
                val_progress.set_postfix({'loss': f"{loss.item():.4f}", 'cer': f"{batch_cer:.4f}"})
        
        # calculate average validation metrics
        try:
            avg_val_loss = val_loss / val_batch_count
            avg_val_cer = val_cer / val_batch_count
            val_losses.append(avg_val_loss)
            val_cers.append(avg_val_cer)
        except ZeroDivisionError:
            print("Division by zero encountered. Ensure val_batch_count is greater than zero.")
            avg_val_loss = 0
            avg_val_cer = 0
            val_losses.append(avg_val_loss)
            val_cers.append(avg_val_cer)

        
        # print epoch summary
        print(f"Epoch {epoch + 1}/{num_epochs}, "
              f"Train Loss: {avg_train_loss:.4f}, Train CER: {avg_train_cer:.4f}, "
              f"Val Loss: {avg_val_loss:.4f}, Val CER: {avg_val_cer:.4f}")
        
        # check for improvement
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            early_stop_counter = 0
            best_model_state = model.state_dict().copy()
            print(f"New best validation loss: {best_loss:.4f}")
        else:
            early_stop_counter += 1
            print(f"No improvement for {early_stop_counter} epochs")
            
        # early stopping
        if early_stop_counter >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs")
            break
    
    # restore best model
    if best_model_state:
        model.load_state_dict(best_model_state)
    
    # return training history
    history = {
        'train_loss': train_losses,
        'val_loss': val_losses,
        'train_cer': train_cers,
        'val_cer': val_cers,
        'lr': lrs
    }
    
    return model, history

# %% [markdown]
# ## Model Training

# %%
num_characters = len(char_to_num)

# model initialisation
model = build_model(num_characters)
model
# Out:
# HandwritingRecognitionModel(
#   (cnn): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (4): Dropout2d(p=0.5, inplace=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Dropout2d(p=0.5, inplace=False)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): Dropout2d(p=0.5, inplace=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
import time

# model training
start = time.perf_counter()
trained_model, history = train_model(model, train_loader, val_loader)
end = time.perf_counter()

# %%
# plot training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history['train_loss'][3:], label='Training Loss')
plt.plot(history['val_loss'][3:], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# plot training and validation CER
plt.subplot(1, 2, 2)
plt.plot(history['train_cer'][3:], label='Training CER')
plt.plot(history['val_cer'][3:], label='Validation CER')
plt.xlabel('Epochs')
plt.ylabel('CER')
plt.title('Training and Validation CER')
plt.legend()

plt.tight_layout()
plt.show()

print('Training Time:', round(end - start, 2))
# Out:
# Training Time: 4495.95

# %%
# epoch index with the lowest loss and cer
best_epoch_loss = np.argmin(history['val_loss']) 
best_epoch_cer = np.argmin(history['val_cer']) 

best_loss = history['val_loss'][best_epoch_loss]
best_cer = history['val_cer'][best_epoch_cer]

print(f"Validation loss at best epoch ({best_epoch_loss}): {best_loss}")
print(f"Validation CER at best epoch ({best_epoch_cer}): {best_cer}")
# Out:
# Validation loss at best epoch (48): 3.872493016525982
# Validation CER at best epoch (48): 0.03486681041656809

# %% [markdown]
# ## Evaluation

# %%
# calculate Character Error Rate (CER)
def calculate_cer(y_true, y_pred):
    total_cer = 0
    for true, pred in zip(y_true, y_pred):
        total_cer += editdistance.eval(true, pred) / max(len(true), 1)
    return total_cer / len(y_true)

# calculate Word Error Rate (WER)
def calculate_wer(y_true, y_pred):
    total_wer = 0
    for true, pred in zip(y_true, y_pred):
        true_words = true.split()
        pred_words = pred.split()
        total_wer += editdistance.eval(true_words, pred_words) / max(len(true_words), 1)  # Avoid division by zero
    return total_wer / len(y_true)

# %%
def greedy_decode(predictions):
    argmax_preds = torch.argmax(predictions, dim=2)
    
    output_texts = []
    for pred in argmax_preds:
        collapsed_preds = torch.unique_consecutive(pred[pred != 0]).cpu().numpy()
        result_text = "".join(num_to_char[idx] for idx in collapsed_preds) 
        result_text = result_text.replace("<PAD>", "").strip()
        output_texts.append(result_text)
    
    return output_texts

def decode_batch_predictions(pred):
    pred = F.log_softmax(pred, dim=2)
    return greedy_decode(pred)

def decode_label(label):
    return "".join(num_to_char[idx.item()] for idx in label if idx != -1)

# %%
def get_predictions_and_ground_truth(model, dataloader, num_samples=10):
    model.eval()
    device = next(model.parameters()).device
    
    batch_images, labels = next(iter(dataloader))
    batch_images = batch_images.to(device)
    
    with torch.no_grad():
        outputs = model(batch_images)
    
    outputs = outputs.cpu()
    predictions = []
    ground_truth = []
    images = []
    
    for i in range(min(num_samples, len(labels))):
        pred_sequence = outputs[i].argmax(dim=1)
        pred_chars = []
        prev_char = None

        # decode prediction
        for idx in pred_sequence:
            char = num_to_char[idx.item()]
            if char != prev_char and char != '<PAD>':
                pred_chars.append(char)
            prev_char = char
        
        # decode ground truth
        true_chars = []
        for idx in labels[i]:
            char = num_to_char[idx.item()]
            if char != '<PAD>':
                true_chars.append(char)
        
        if len(pred_chars) > 0:
            predictions.append(''.join(pred_chars))
            ground_truth.append(''.join(true_chars))
            images.append(batch_images[i].cpu().numpy())
    
    return ground_truth, predictions, images

ground_truth, predictions, images = get_predictions_and_ground_truth(model, val_loader)
# Out:
# /tmp/ipykernel_111/2433137277.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   label = torch.tensor(self.labels[idx], dtype=torch.long)

# %%
print("Character Error Rate:", calculate_cer(ground_truth, predictions))
print("Word Error Rate:", calculate_wer(ground_truth, predictions))
# Out:
# Character Error Rate: 0.06315789473684211
# Word Error Rate: 0.13333333333333333

# %%
def visualize_results(images, ground_truth, predictions):
    for i in range(len(predictions)):
        print(f"\nSample {i+1}:")
        print(f"Ground Truth: {ground_truth[i]}")
        print(f"Prediction:   {predictions[i]}")
        
        plt.figure(figsize=(15, 3))
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.axis('off')
        plt.show()
        plt.close()

visualize_results(images, ground_truth, predictions)
# Out:
# Sample 1:
# Ground Truth: and respectful.
# Prediction:   and respectful.
# Sample 2:
# Ground Truth: one
# Prediction:   one
# Sample 3:
# Ground Truth: friends broke
# Prediction:   friends broke
# Sample 4:
# Ground Truth: comparison is ok to
# Prediction:   comparison is ok to
# Sample 5:
# Ground Truth: needed by humans to
# Prediction:   needed by humans to
# Sample 6:
# Ground Truth: clear, but why is it even
# Prediction:   clear, but why is it even
# Sample 7:
# Ground Truth: developments in AI-generated
# Prediction:   developments in AI-generated
# Sample 8:
# Ground Truth: also a possibility of an asteroid,
# Prediction:   also a possibility of an asteroid,
# Sample 9:
# Ground Truth: digital clone. And
# Prediction:   digital clone. And
# Sample 10:
# Ground Truth: introduces a change
# Prediction:   ntre lls is a mense

# %%
print("Sample ground truth and predictions:")
for gt, pred in zip(ground_truth[:5], predictions[:5]):
    print(f"Ground truth: '{gt}'")
    print(f"Prediction:   '{pred}'")
    print()

print("Lengths of first 5 samples:")
for gt, pred in zip(ground_truth[:5], predictions[:5]):
    print(f"Ground truth length: {len(gt)}, Prediction length: {len(pred)}")
# Out:
# Sample ground truth and predictions:
# Ground truth: 'and respectful.'
# Prediction:   'and respectful.'
#
# Ground truth: 'one'
# Prediction:   'one'
#
# Ground truth: 'friends broke'
# Prediction:   'friends broke'
#
# Ground truth: 'comparison is ok to'
# Prediction:   'comparison is ok to'
#
# Ground truth: 'needed by humans to'
# Prediction:   'needed by humans to'
#
# Lengths of first 5 samples:
# Ground truth length: 15, Prediction length: 15
# Ground truth length: 3, Prediction length: 3
# Ground truth length: 13, Prediction length: 13
# Ground truth length: 19, Prediction length: 19
# Ground truth length: 19, Prediction length: 19

# %%
from collections import Counter

def analyze_error_patterns(ground_truth, predictions):
    errors = []
    for true, pred in zip(ground_truth, predictions):
        true = true.replace("<PAD>", "").strip()
        pred = pred.replace("<PAD>", "").strip()
        if true != pred and true and pred:
            errors.append((true, pred))
    
    print("Top 10 most common errors:")
    for (true, pred), count in Counter(errors).most_common(10):
        print(f"True: '{true}' -> Predicted: '{pred}' (Count: {count})")

# run the analysis
analyze_error_patterns(ground_truth, predictions)
# Out:
# Top 10 most common errors:
# True: 'introduces a change' -> Predicted: 'ntre lls is a mense' (Count: 1)

# %%
torch.save(model.state_dict(), 'model_state.pth')
